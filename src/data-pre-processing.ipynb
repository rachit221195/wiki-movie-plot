# %%
import pandas as pd
import numpy as np

import re

# %%
from utils import WikiMoviePlots

# %%
wiki_plots = WikiMoviePlots()

# %%
data_df = wiki_plots.data

# %%
data_df
# Out:
#       movie_id  Release Year  \
# 0          M_0          1901
# 1          M_1          1901
# 2          M_2          1901
# 3          M_3          1901
# 4          M_4          1902
# 5          M_5          1903
# 6          M_6          1903
# 7          M_7          1904
# 8          M_8          1905
# 9          M_9          1905
# 10        M_10          1906
# 11        M_11          1906
# 12        M_12          1906
# 13        M_13          1907
# 14        M_14          1907
# 15        M_15          1907
# 16        M_16          1908
# 17        M_17          1908
# 18        M_18          1908
# 19        M_19          1908
# 20        M_20          1908
# 21        M_21          1908
# 22        M_22          1909
# 23        M_23          1909
# 24        M_24          1909
# 25        M_25          1909
# 26        M_26          1910
# 27        M_27          1910
# 28        M_28          1910
# 29        M_29          1910
# ...        ...           ...
# ...

# %%
plots_data = wiki_plots.get_plot_data()
# Out:
# /Users/rachitjain/Desktop/Projects/wiki-movie-plot/src/utils.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.plot_data['genres'] = self.plot_data['genre'].apply(self._split_it)
# /Users/rachitjain/Desktop/Projects/wiki-movie-plot/src/utils.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.plot_data['genre_len'] = self.plot_data['genres'].apply(len)

# %%
plots_data.head()
# Out:
#   movie_id                                               plot     genres
# 0      M_0  A bartender is working at a saloon, serving dr...  [unknown]
# 1      M_1  The moon, painted with a smiling face hangs ov...  [unknown]
# 2      M_2  The film, just over a minute long, is composed...  [unknown]
# 3      M_3  Lasting just 61 seconds and consisting of two ...  [unknown]
# 4      M_4  The earliest known adaptation of the classic f...  [unknown]
